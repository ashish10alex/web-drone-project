# %%
import os
import random
import pandas as pd
import yaml
yaml.Dumper.ignore_aliases = lambda *args : True
import itertools
pd.set_option('display.max_colwidth', None)

# %%
random.seed(1)

# %%
models =['Clean', 'Noisy', 'DCUNet', 'DPTNet', 'RegressionFCNN', 'SMoLnet', 'WaveUNet']
# snrs = ['0', '-5', '-10', '-15', '-20', '-25', '-30']
snrs = ['-10', '-15', '-20', '-25']
df_all_snr_dict = {
#     '0': '', 
#     '-5': '',
    '-10': '',
    '-15': '',
    '-20': '',
    '-25': '',
#     '-30' : ''
}

# %%
meta_data_dir = 'meta_data_for_yaml'
for snr in snrs:
    df_all_snr_dict[str(snr)] = pd.read_csv(f'meta_data_for_yaml/website_meta_data_snr_{snr}dB.csv', index_col=False, 
                                           usecols = ['Clean', 'Noisy', 'RegressionFCNN'])

# %%
# list([df_all_snr_dict['-5'].iloc[1][0]])

# list(itertools.combinations(list(df_all_snr_dict['-5'].iloc[1][1:]), 2))

# %%
# df_all_snr_dict['-5']

# %%
#get big dataframe
# df = pd.concat([df_all_snr_dict['0'], df_all_snr_dict['-5'], df_all_snr_dict['-10'], df_all_snr_dict['-15'], df_all_snr_dict['-20'], df_all_snr_dict['-25'], df_all_snr_dict['-30']], ignore_index=True)

df = pd.concat([df_all_snr_dict['-10'], df_all_snr_dict['-15'], df_all_snr_dict['-20'], df_all_snr_dict['-25']], ignore_index=True)

# %%
def get_combinations_of_index(df, idx):
    #all wavs except for the input to create combinations
    #Input will be our reference
    denoised_list = list(df.iloc[idx])[1:]
    #create pairs of twos
    #e.g. - (WaveUNet_SX139.WAV.n121.wav, RegressionFCNN_SX139.WAV.n121.wav) ...
    combinations = list(itertools.combinations(denoised_list, 2))

    # Final combination list with input appended to all 
    #e.g. - (input.wav, WaveUNet_SX139.WAV.n121.wav, RegressionFCNN_SX139.WAV.n121.wav) ...
    final_combination_list = []
    for c in combinations:
        #trick to append to tuple 
        c = (df.iloc[idx][0], *c)
        final_combination_list.append(c)
    return final_combination_list

# %%
final_list = []

# %%
for i in range(len(df)):
    res = get_combinations_of_index(df, i)
    for r in res:
        final_list.append(r)

# %%
#shuffle the list in place
random.shuffle(final_list)

# %%
def make_yaml_file(combinations, idx_meta='0_20'):
    print(f'''
    {len(combinations)} pages will be created for subjective evalutation
    ''')
    
    final_dict_template = {
    'testname': 'AB Test',
     'testId': 'ab_noloop',
     'bufferSize': 2048,
     'stopOnErrors': True,
     'showButtonPreviousPage': True,
     'remoteService': 'service/write.php',
     'pages': []
    }
    #final page which sends results
    final_page_template =  {'type': 'finish',
       'name': 'Thank you',
       'content': 'Thank you for attending',
       'showResults': False,
       'writeResults': True,
       'questionnaire':[
           {
               'type':'text',
               'label': 'Name',
               'name': 'name'
           },
           {
               'type':'text',
               'label': 'Email',
               'name': 'email'
           },
           {
               'type':'likert',
               'name':'age',
               'label':'Age',
               'response':[
                   {'value': '0-20',
                   'label':'0 to 20',},
                    {'value': '20-40',
                   'label':'20 to 40',},
                    {'value': '20-40',
                   'label':'40 to 60',},
                    {'value': '40-60',
                   'label':'40 to 60',}
                   
               ]
           },
           {
               'type':'likert',
               'name':'gender',
               'label':'Gender',
               'response':[
                   {'value': 'female',
                   'label':'Female',},
                    {'value': 'male',
                   'label':'Male',},
                    {'value': 'other',
                   'label':'Other',},
               ]
           },
               {
               'type':'likert',
               'name':'subjective_eval_ever',
               'label':'Have you participated in audio subjective evailation before',
               'response':[
                   {'value': 'yes',
                   'label':'Yes',},
                    {'value': 'no',
                   'label':'No',},
               ]
           }
       ]
    }
    welcome_page_template = {
        'type': 'generic',
        'id': 'first_page',
        'name': 'Welcome',
        'content': '<b>Welcome to AB testing framework for DRONE ego noise ehancement. You will be presented a reference audio clip and denoised audio clip from two separate algorithms. You will be required to select one of the two clips which sounds the closest to the reference audio clip. </b>'
    }
    pages=[]
    pages.append(welcome_page_template)
    for i in range(1, len(combinations)):
        pages_dict_template = {'type': 'paired_comparison',
         'id': 'trialAB2',
         'name': None,
         'unforced': None,
         'content': 'test description AB',
         'showWaveform': True,
         'enableLooping': False,
         'reference': '',
         'stimuli': {'C1': '',
          'C2': ''}}
        pages.append(pages_dict_template)
        pages[i]['reference'] = combinations[i][0]
        pages[i]['stimuli']['C1'] = combinations[i][1]
        pages[i]['stimuli']['C2'] = combinations[i][2]
    
    pages.append(final_page_template)
    final_dict_template['pages'] = pages
    
    # dict to yaml
    yam_file_path = f'/Users/ashishalex/Documents/research/web_drone_project/pymushra/pymushra/static/yamls/baseline_vs_noisy/baseline_idx{idx_meta}.yaml'
    with open(yam_file_path, 'w') as f:
        yaml.dump(final_dict_template, f)
    print('Created yaml file at: ', yam_file_path)
    
    return final_dict_template

# %%
#window paramerter defines how many combinations (Reference, A, B) will the participant see
window = 20
start  = 0
ranges = []
while start < len(final_list):
    if start + window > len(final_list):
        ranges.append([start, len(final_list)])
        start+=window
    else:
        ranges.append([start, start+ window])
        start +=window

# %%
for start, end in ranges:
    out = make_yaml_file(combinations=final_list[start:end], idx_meta=f'{start}_{end}')
# Out:
#     20 pages will be created for subjective evalutation
#
# Created yaml file at:  /Users/ashishalex/Documents/research/web_drone_project/pymushra/pymushra/static/yamls/baseline_vs_noisy/baseline_idx0_20.yaml
#
#     20 pages will be created for subjective evalutation
#
# Created yaml file at:  /Users/ashishalex/Documents/research/web_drone_project/pymushra/pymushra/static/yamls/baseline_vs_noisy/baseline_idx20_40.yaml
#
#     20 pages will be created for subjective evalutation
#
# Created yaml file at:  /Users/ashishalex/Documents/research/web_drone_project/pymushra/pymushra/static/yamls/baseline_vs_noisy/baseline_idx40_60.yaml

# %%
len(final_list)
# Out:
# 60

# %%
final_list
# Out:
# [('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SI740.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SI740.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-15dB/data/RegressionFCNN_SI740.WAV.n122.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SI1370.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SI1370.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-25dB/data/RegressionFCNN_SI1370.WAV.n121.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SX229.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SX229.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-15dB/data/RegressionFCNN_SX229.WAV.n122.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SA2.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SA2.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-10dB/data/RegressionFCNN_SA2.WAV.n122.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SX319.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SX319.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-10dB/data/RegressionFCNN_SX319.WAV.n121.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SX49.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SX49.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-10dB/data/RegressionFCNN_SX49.WAV.n122.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SX409.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SX409.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-15dB/data/RegressionFCNN_SX409.WAV.n121.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SX200.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SX200.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-20dB/data/RegressionFCNN_SX200.WAV.n121.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SX319.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SX319.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-25dB/data/RegressionFCNN_SX319.WAV.n121.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SA1.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SA1.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-15dB/data/RegressionFCNN_SA1.WAV.n121.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SI2000.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SI2000.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-25dB/data/RegressionFCNN_SI2000.WAV.n122.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SX20.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SX20.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-15dB/data/RegressionFCNN_SX20.WAV.n121.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SI1759.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SI1759.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-15dB/data/RegressionFCNN_SI1759.WAV.n122.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SX20.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SX20.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-10dB/data/RegressionFCNN_SX20.WAV.n121.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SX409.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SX409.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-10dB/data/RegressionFCNN_SX409.WAV.n121.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SI740.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SI740.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-10dB/data/RegressionFCNN_SI740.WAV.n122.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SI1370.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SI1370.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-15dB/data/RegressionFCNN_SI1370.WAV.n121.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SA1.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SA1.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-20dB/data/RegressionFCNN_SA1.WAV.n121.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SX139.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SX139.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-15dB/data/RegressionFCNN_SX139.WAV.n122.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SX49.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SX49.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-20dB/data/RegressionFCNN_SX49.WAV.n122.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SA1.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SA1.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-25dB/data/RegressionFCNN_SA1.WAV.n121.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SX229.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SX229.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-25dB/data/RegressionFCNN_SX229.WAV.n122.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SX20.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SX20.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-20dB/data/RegressionFCNN_SX20.WAV.n121.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SX139.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SX139.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-25dB/data/RegressionFCNN_SX139.WAV.n122.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SI1759.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SI1759.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-20dB/data/RegressionFCNN_SI1759.WAV.n122.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SI499.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SI499.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-15dB/data/RegressionFCNN_SI499.WAV.n121.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SI2000.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SI2000.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-10dB/data/RegressionFCNN_SI2000.WAV.n122.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SX49.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SX49.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-25dB/data/RegressionFCNN_SX49.WAV.n122.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SX200.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SX200.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-25dB/data/RegressionFCNN_SX200.WAV.n121.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SX409.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SX409.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-20dB/data/RegressionFCNN_SX409.WAV.n121.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SA2.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SA2.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-20dB/data/RegressionFCNN_SA2.WAV.n122.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SX319.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SX319.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-20dB/data/RegressionFCNN_SX319.WAV.n121.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SI2000.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SI2000.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-20dB/data/RegressionFCNN_SI2000.WAV.n122.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SX49.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SX49.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-15dB/data/RegressionFCNN_SX49.WAV.n122.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SI1370.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SI1370.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-20dB/data/RegressionFCNN_SI1370.WAV.n121.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SI1370.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SI1370.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-10dB/data/RegressionFCNN_SI1370.WAV.n121.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SX319.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SX319.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-15dB/data/RegressionFCNN_SX319.WAV.n121.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SI1759.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SI1759.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-25dB/data/RegressionFCNN_SI1759.WAV.n122.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SX139.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SX139.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-10dB/data/RegressionFCNN_SX139.WAV.n122.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SX229.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SX229.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-20dB/data/RegressionFCNN_SX229.WAV.n122.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SI2000.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SI2000.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-15dB/data/RegressionFCNN_SI2000.WAV.n122.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SI1129.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SI1129.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-25dB/data/RegressionFCNN_SI1129.WAV.n122.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SI1129.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SI1129.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-10dB/data/RegressionFCNN_SI1129.WAV.n122.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SI740.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SI740.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-25dB/data/RegressionFCNN_SI740.WAV.n122.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SI499.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SI499.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-10dB/data/RegressionFCNN_SI499.WAV.n121.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SX200.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SX200.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-10dB/data/RegressionFCNN_SX200.WAV.n121.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SA2.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SA2.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-15dB/data/RegressionFCNN_SA2.WAV.n122.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SI740.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SI740.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-20dB/data/RegressionFCNN_SI740.WAV.n122.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SX139.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SX139.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-20dB/data/RegressionFCNN_SX139.WAV.n122.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SX200.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SX200.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-15dB/data/RegressionFCNN_SX200.WAV.n121.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SX20.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SX20.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-25dB/data/RegressionFCNN_SX20.WAV.n121.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SI1129.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SI1129.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-20dB/data/RegressionFCNN_SI1129.WAV.n122.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SA1.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SA1.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-10dB/data/RegressionFCNN_SA1.WAV.n121.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SI1129.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SI1129.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-15dB/data/RegressionFCNN_SI1129.WAV.n122.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SI1759.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SI1759.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-10dB/data/RegressionFCNN_SI1759.WAV.n122.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SX409.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SX409.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-25dB/data/RegressionFCNN_SX409.WAV.n121.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SI499.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SI499.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-25dB/data/RegressionFCNN_SI499.WAV.n121.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SA2.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SA2.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-25dB/data/RegressionFCNN_SA2.WAV.n122.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SI499.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SI499.WAV.n121.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-20dB/data/RegressionFCNN_SI499.WAV.n121.wav'),
#  ('static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Clean/clean_SX229.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/Noisy/noisy_SX229.WAV.n122.wav',
#   'static/configs/resources/Drone_Noise_Test_Data/drone_noise_out/RegressionFCNN/-10dB/data/RegressionFCNN_SX229.WAV.n122.wav')]
